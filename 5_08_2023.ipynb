# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresfelipeZaGa/Fundamentos/blob/main/5_08_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Algoritmo que suma dos variables

# %%
valorA= 77
ValorB= 33
suma= valorA + ValorB
print("El resultado es: ", suma)
# Out:
# El resultado es:  110

# %% [markdown]
# Algoritmo que resta dos variables![Resta.png](data:image/png;base64,...)

# %%
valorA= 77
ValorB= 33
resta= valorA - ValorB
print("El resultado es: ", resta)
# Out:
# El resultado es:  44

# %% [markdown]
# Ejercicio comentario y acciones basicas

# %%
# v es tipo int y su valor asignado es -3
valorA= 77
ValorB= 33
Division= valorA / ValorB
print("El resultado es: ", Division)
# Out:
# El resultado es:  2.3333333333333335

# %% [markdown]
# Algoritmo para la division sin manejo de excepcion por cero

# %%
# algoritmo que realiza la division de dos enteros
# numA= int(input("ingresa el valor a"))
# resultado = numA +10
# print("has ingresado el valor:", resultado)
numA= int(input("Ingresa el valor del numerador: "))
numB= int(input("Ingresa el valor del divisor: "))
if numB==0:
    print("has ingresado un valor 0")
else:
    res= numA/numB
    print("El resultado es: ", res)
# Out:
# Ingresa el valor del numerador: 5
# Ingresa el valor del divisor: 0
# has ingresado un valor 0

# %% [markdown]
# Algoritmo que muestre si un nombre tiene mas de 4 letras

# %%
# nom= input("ingresa el nombre por favor ")
# lc=len(nom)
# print("La longitud es: ", lc)
nom= input("ingresa el nombre por favor: ")
lc=len(nom)
if lc>4:
    print("El nombre ingresado tiene mas de 4 letras.")
else:
    print("El nombre ingresado tiene menos de 4 letras")
# Out:
# ingresa el nombre por favor: leo
# El nombre ingresado tiene menos de 4 letras

# %% [markdown]
# redondeo de division

# %%
numA= int(input("Ingresa el valor del numerador: "))
numB= int(input("Ingresa el valor del divisor: "))
if numB==0:
    print("has ingresado un valor 0")
else:
    res= numA/numB
    print("El resultado es: ", round(res, 2))
# Out:
# Ingresa el valor del numerador: 43
# Ingresa el valor del divisor: 41
# El resultado es:  1.05

# %% [markdown]
# Numeros Elevados
# Algoritmo que solicita al usuario el valor de la pótencia y la base y muestra el resultado de la operacion. ej: a**b

# %%
a= int(input("ingresa el valor de la potencia "))
b= int(input("ingresa el valor de la base "))
potencia= a**b
print("el resultado es: ", potencia)
# Out:
# ingresa el valor de la potencia 5
# ingresa el valor de la base 2
# el resultado es:  25

# %% [markdown]
# Algoritmo que pide un valor numerico n al usuario y muestra su raiz cuadrada y cubica

# %%
n= int(input("ingresa el valor numerico "))
res = n**(1/2)
print("la raiz cuadrada es: ", round(res, 2))
res1= n**(1/3)
print("la raiz cubica es: ", round(res1, 2))
# Out:
# ingresa el valor numerico 18
# la raiz cuadrada es:  4.24
# la raiz cubica es:  2.62

# %% [markdown]
# Algoritmo para division entera

# %%
# division entera
# ingresa numerador y divisor
b= int(input("Ingresa el valor del numerador: "))
c= int(input("Ingresa el valor del divisor: "))
c= b//4
print(c)
# Out:
# Ingresa el valor del numerador: 5
# Ingresa el valor del divisor: 3
# 1

# %% [markdown]
# variables booleanas

# %%
a= False
b= True
type(a)
print(type(a))
# Out:
# <class 'bool'>

# %% [markdown]
# Algoritmo que solicita al usuario un valor n y se muestra en pantalla si es par

# %%
n= int(input("ingresa el valor numerico "))
bool(n)
if n
    print("es par")
else:
    print("es impar")
    res= n

# %% [markdown]
# Algoritmo que pida al usuario 3 valores y mediante un booleano imprime un mensaje solo cuando son iguales a=b=c

# %%
a = int(input("ingresa primer valor "))
b = int(input("ingresa segundo valor "))
c = int(input("ingresa tercer valor "))
bool (a==b==c)
if a==b==c:
    print("los valores que ingreso son iguales")
else:
    print("los valores no son iguales")
# Out:
# ingresa primer valor 5
# ingresa segundo valor 5
# ingresa tercer valor 5
# los valores que ingreso son iguales

# %% [markdown]
# Algoritmo que pide al usuario una frase y luego evalua si existe en ella la palabra "terrorismo", en caso positivo muestra un mensaje : alerta

# %%
f= input("ingresa por favor una frase: ")
if "terrorismo" "matar" in f:
    print("alerta")
# Out:
# ingresa por favor una frase: que viva el terrorismo

# %% [markdown]
# Algoritmo que evalua si un entero ingresado por el usuario es positivo o no

# %%
n= int(input("ingresa un numero entero: "))
if n==0:
    print("es positivo")
else:
    print("no es positivo")
# Out:
# ingresa un numero entero: 0
# es positivo

# %% [markdown]
# Algoritmo que evalua si un entero ingresado por el usuario es positivo o no, o es igual a 0

# %%
n= int(input("ingresa por favor un numero entero: "))
if n>0:
    print("es positivo")
elif n==0:
    print("es 0")
else:
    print("es negativo")
# Out:
# ingresa por favor un numero entero: 0
# es igual a 0

# %% [markdown]
# Algoritmo que pida al usuario ingresar el nombre y muestre cuantas vocales tiene y las discrimine

# %%
from typing_extensions import Counter
nom= input("por favor ingresa el nombre: ")
if "a" in nom:
    print("a")
if "e" in nom:
    print("e")
if "i" in nom:
    print("i")
if "o" in nom:
    print("o")
if "u" in nom:
    print("u")
Counter(nom)
# Out:
# por favor ingresa el nombre: santiago
# a
# i
# o
# Counter({'s': 1, 'a': 2, 'n': 1, 't': 1, 'i': 1, 'g': 1, 'o': 1})

# %% [markdown]
# Algoritmo boletas para entradas a estadio

# %%
#primera parte fines de semana
n=0
fecha=""
tb=5
costtal=0
fecha=input("La boleta es para fin de semana?(si o no) ")
n=int(input("Ingresa la cantidad de boletas a comprar: "))
if fecha=="si":
    costtal=tb*1.20
else:
    costtal=tb
print ("el costo total a pagar: ", costtal*n)
#segunda parte
palco=""
palco=input("La boleta es para cual palco?(a, b o c) ")
if palco=="a":
    costtal= costtal + tb*.1
elif palco=="b":
    costtal= costtal + tb*.05
else:
    pC=tb
print ("el costo total con palco es: ", costtal*n)
#tercera parte
Descuento=""
des1=.1
des2=.15
des3=.2
print ("El descuento de promocion para 5-10 boletas seria: ", costtal-des1)
print ("El descuento de promocion para 15-20 boletas seria: ", costtal-des2)
print ("El descuento de promocion para 25 o mas boletas seria: ", costtal-des3)
# Out:
# La boleta es para fin de semana?(si o no) si
# Ingresa la cantidad de boletas a comprar: 1
# el costo total a pagar:  6.0
# La boleta es para cual palco?(a, b o c) a
# el costo total con palco es:  6.5
# El descuento de promocion para 5-10 boletas seria:  6.4
# El descuento de promocion para 15-20 boletas seria:  6.35
# El descuento de promocion para 25 o mas boletas seria:  6.3
